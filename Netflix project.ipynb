# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/netflix_advanced_dataset.csv")

# %%
df.head()
# Out:
#   show_id     type    title    director              cast         country  \
# 0  s00000    Movie  Title 0  Director D  Actor X, Actor Y  United Kingdom
# 1  s00001  TV Show  Title 1  Director C  Actor M, Actor N  United Kingdom
# 2  s00002    Movie  Title 2  Director B  Actor X, Actor Y     South Korea
# 3  s00003    Movie  Title 3  Director A  Actor M, Actor N   United States
# 4  s00004    Movie  Title 4  Director B  Actor X, Actor Y     South Korea
#
#             date_added  release_year rating    duration    listed_in  \
# 0  2020-07-22 14:20:51          1954  TV-PG      30 min       Action
# 1  2022-06-03 21:53:37          1991  TV-MA  14 Seasons  Documentary
# 2  2023-03-04 12:17:51          2010  NC-17      84 min       Action
# 3  2020-02-24 13:31:46          1971  TV-MA     113 min       Comedy
# 4  2021-08-28 11:14:33          1970  TV-PG      25 min       Action
#
#                           description
# 0  Sample description of the content.
# 1  Sample description of the content.
# 2  Sample description of the content.
# 3  Sample description of the content.
# 4  Sample description of the content.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1200 non-null   object
#  1   type          1200 non-null   object
#  2   title         1200 non-null   object
#  3   director      1200 non-null   object
#  4   cast          1200 non-null   object
#  5   country       1200 non-null   object
#  6   date_added    1200 non-null   object
#  7   release_year  1200 non-null   int64
#  8   rating        1200 non-null   object
#  9   duration      1200 non-null   object
#  10  listed_in     1200 non-null   object
#  11  description   1200 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 112.6+ KB

# %%
df.size
# Out:
# 14400

# %%
df.shape
# Out:
# (1200, 12)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.describe()
# Out:
#        release_year
# count   1200.000000
# mean    1986.451667
# std       21.581260
# min     1950.000000
# 25%     1968.000000
# 50%     1986.000000
# 75%     2005.000000
# max     2024.000000

# %%
df['type'].value_counts()
# Out:
# type
# Movie      601
# TV Show    599
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df['type'].value_counts().plot(kind='bar')
plt.title("Movies vs TV Shows")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United Kingdom    215
# South Korea       211
# United States     209
# Japan             193
# India             189
# Canada            183
# Name: count, dtype: int64

# %%
df['country'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Countries")
plt.xlabel("Country")
plt.ylabel("Number of Shows")
plt.show()

# %%
df['rating'].value_counts()
# Out:
# rating
# R        174
# PG       158
# NC-17    153
# PG-13    151
# TV-14    148
# TV-MA    140
# G        139
# TV-PG    137
# Name: count, dtype: int64

# %%
df['rating'].value_counts().plot(kind='bar')

plt.title("Content Ratings")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
df['release_year'].plot(kind='hist', bins=20)

plt.title("Release Year Distribution")
plt.xlabel("Year")
plt.show()
